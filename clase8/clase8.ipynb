# %%
import numpy as np
import matplotlib.pyplot as plt
from ztrans import *

# %% [markdown]
# $y(n)=x(n-1) + 8x(n-1) - 2y(n-2) + 5y(n-1)$

# %% [markdown]
# ## Dada la anterior expresión, es posible es posible encontrar un la función de transferencia?

# %% [markdown]
# $Y(z)[1 - 2z^{-2} - 5z^{-1} ] =  X(z) [8z^{-1} + 1]$

# %% [markdown]
# Antes que nada es importante entender que la función de transferencia se haya en el dominio de Z, por tanto se realizo previamente la transformación, si embargo es necesario hayar también la ROC

# %% [markdown]
# $ROC = Z excepto, Z = 0$

# %% [markdown]
# $Y(z)[1 - 2z^{-2} - 5z^{-1} ] =  X(z) [8z^{-1} + 1]$
#
# $H(z)= \frac{8z^{-1} + 1} {1 + 2z^{-2} -5z^{-1}}$

# %% [markdown]
# ## Y finalmente se logra observar una expresión para la función de tranferencia

# %% [markdown]
# Ahora, encontrar el diagrama de polos apartir de la anterior expresión.

# %% [markdown]
# $H(z)= \frac{8z^{-1} + 1} {1 + 2z^{-2} -5z^{-1}}$ * $\frac{z^{2}} {z^{2}}$

# %% [markdown]
# $H(z)= \frac{z^{2} + 8z} {z^{2} - 5z + 2}$

# %% [markdown]
# Y posteriormente hayar la region unitaria

# %%
num=[1,8,0]
den=[1,-5,2]
zeropoles(num,den)

# %% [markdown]
# ## Se puede observar que un cero esta localizado en z=0 y en z=8. Por otro lado se observar que los polos estan localizados en z = 4,561 y en z = 0,438.

# %% [markdown]
# ## Apatir de ahora es posible realizar analisis de estabilidad y de causalidad del sistema.
