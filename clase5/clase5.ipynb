# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.arange(-1,4)

# %%
h_n = np.array([5, 8, 3])  #Suponga que h(n) tiene el cero en 8 
x_n = np.array([1, 6, 8])  #Suponga que x(n) tiene el cero en 1

# %%
y_n = np.convolve(h, x)       # Función que realiza la convolución

# %%
# Grafica de la convolución
plt.figure()
plt.stem(time, y_n)
plt.xlabel('Valores en el tiempo')
plt.ylabel('Amplitud')
plt.grid()
plt.show()
